# %% [markdown]
# ### Classification of vibrato type from hand movement sensors

# %%
import numpy as np
import scipy
import matplotlib.pyplot as plt
import os

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow.keras.datasets import imdb
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Embedding
from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.utils import to_categorical
# fix random seed for reproducibility
tf.random.set_seed(666)

# %%
# load all data
X = []
y = []
max_seq_size = 0
data_path = "data-processed"
data_points = [point for point in os.listdir(data_path) if point != '.DS_Store']
for dir in data_points:
    data_point_path = os.path.join(data_path, dir)
    for file_name in os.listdir(data_point_path):
        #print(file_name)
        if file_name.endswith('.npy'):
            filepath = os.path.join(data_point_path, file_name)
            file = np.load(filepath)
            if file.shape[1] > max_seq_size:
                max_seq_size = file.shape[1]
            X.append(file)
            if file_name.split('-')[1] == 'static':
                y.append(0) # static
            if file_name.split('-')[1] == 'vertical':
                y.append(1) # vertical
            if file_name.split('-')[1] == 'horizontal':
                y.append(2) # horizontal
            if file_name.split('-')[1] == 'circular':
                y.append(3) # circular
print(f'Max sequence size: {max_seq_size}')
# Out:
# Max sequence size: 129

# %%
# format sequences
X_acc_x = np.zeros(len(X), dtype=object)
X_acc_y = np.zeros(len(X), dtype=object)
X_acc_z = np.zeros(len(X), dtype=object)
X_gyro_x = np.zeros(len(X), dtype=object)
X_gyro_y = np.zeros(len(X), dtype=object)
X_gyro_z = np.zeros(len(X), dtype=object)

for i in range(X_array.shape[0]):
    X_acc_x[i] = X[i][0,:].tolist()
    X_acc_y[i] = X[i][1,:].tolist()
    X_acc_z[i] = X[i][2,:].tolist()
    X_gyro_x[i] = X[i][3,:].tolist()
    X_gyro_y[i] = X[i][4,:].tolist()
    X_gyro_z[i] = X[i][5,:].tolist()

# %%
# pad sequences
X_acc_x_padded = sequence.pad_sequences(X_acc_x, maxlen=max_seq_size, dtype='float32', padding='post')
X_acc_y_padded = sequence.pad_sequences(X_acc_y, maxlen=max_seq_size, dtype='float32', padding='post')
X_acc_z_padded = sequence.pad_sequences(X_acc_z, maxlen=max_seq_size, dtype='float32', padding='post')
X_gyro_x_padded = sequence.pad_sequences(X_gyro_x, maxlen=max_seq_size, dtype='float32', padding='post')
X_gyro_y_padded = sequence.pad_sequences(X_gyro_y, maxlen=max_seq_size, dtype='float32', padding='post')
X_gyro_z_padded = sequence.pad_sequences(X_gyro_z, maxlen=max_seq_size, dtype='float32', padding='post')

# %%
# aggregate and normalize
X_temp = np.zeros((6, X_acc_x_padded.reshape(-1).shape[0]))
X_temp[0,:] = X_acc_x_padded.reshape(-1)
X_temp[1,:] = X_acc_y_padded.reshape(-1)
X_temp[2,:] = X_acc_z_padded.reshape(-1)
X_temp[3,:] = X_gyro_x_padded.reshape(-1)
X_temp[4,:] = X_gyro_y_padded.reshape(-1)
X_temp[5,:] = X_gyro_z_padded.reshape(-1)

scaler = StandardScaler().fit(X_temp.T)
X = []
for i in range(X_acc_x_padded.shape[0]):
    X_temp = np.zeros((6, X_acc_x_padded.shape[1]))
    X_temp[0,:] = X_acc_x_padded[i,:]
    X_temp[1,:] = X_acc_y_padded[i,:]
    X_temp[2,:] = X_acc_z_padded[i,:]
    X_temp[3,:] = X_gyro_x_padded[i,:]
    X_temp[4,:] = X_gyro_y_padded[i,:]
    X_temp[5,:] = X_gyro_z_padded[i,:]
    X_temp = scaler.transform(X_temp.T)
    X.append(X_temp) # normalized array of dimensions N_samples, seq_len, num_sensors
np.array(X).shape
# Out:
# (96, 129, 6)

# %%
index = 20

fig, ax = plt.subplots(nrows=6, figsize=(8,6))
ax[0].plot(X[index][:,0])
ax[1].plot(X[index][:,1])
ax[2].plot(X[index][:,2])
ax[3].plot(X[index][:,3])
ax[4].plot(X[index][:,4])
ax[5].plot(X[index][:,5])
fig.suptitle(f'Data point {index}')
# Out:
# Text(0.5, 0.98, 'Data point 20')

# %%
X_train, X_test, y_train, y_test = train_test_split(np.array(X), np.array(y), test_size=0.33, random_state=42)
y_train = to_categorical(y_train, num_classes=4) # one-hot encode
y_test = to_categorical(y_test, num_classes=4)

# %%
number_of_hidden_units = 16
no_of_epochs = 20
batch_size = 32

model = Sequential()
model.add(LSTM(number_of_hidden_units, activation='relu', input_shape=(max_seq_size, 6))) 
model.add(Dense(4, activation='softmax')) #since number of output classes is 4
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=no_of_epochs, batch_size=batch_size)
# Out:
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_12 (LSTM)              (None, 16)                1472
#
#  dense_12 (Dense)            (None, 4)                 68
#
# =================================================================
# Total params: 1540 (6.02 KB)
# Trainable params: 1540 (6.02 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/20
# 2/2 [==============================] - 0s 91ms/step - loss: 1.4669 - accuracy: 0.2188 - val_loss: 1.4390 - val_accuracy: 0.3438
# Epoch 2/20
# 2/2 [==============================] - 0s 16ms/step - loss: 1.4410 - accuracy: 0.2188 - val_loss: 1.4298 - val_accuracy: 0.3438
# Epoch 3/20
# 2/2 [==============================] - 0s 16ms/step - loss: 1.4251 - accuracy: 0.2031 - val_loss: 1.4246 - val_accuracy: 0.2812
# Epoch 4/20
# 2/2 [==============================] - 0s 16ms/step - loss: 1.4041 - accuracy: 0.1875 - val_loss: 1.4215 - val_accuracy: 0.3438
# Epoch 5/20
# 2/2 [==============================] - 0s 16ms/step - loss: 1.3924 - accuracy: 0.2812 - val_loss: 1.4212 - val_accuracy: 0.2812
# Epoch 6/20
# 2/2 [==============================] - 0s 16ms/step - loss: 1.3854 - accuracy: 0.2500 - val_loss: 1.4230 - val_accuracy: 0.2812
# Epoch 7/20
# 2/2 [==============================] - 0s 16ms/step - loss: 1.3801 - accuracy: 0.3438 - val_loss: 1.4254 - val_accuracy: 0.3438
# Epoch 8/20
# 2/2 [==============================] - 0s 17ms/step - loss: 1.3745 - accuracy: 0.3594 - val_loss: 1.4277 - val_accuracy: 0.2188
# Epoch 9/20
# 2/2 [==============================] - 0s 15ms/step - loss: 1.3717 - accuracy: 0.3438 - val_loss: 1.4299 - val_accuracy: 0.2188
# Epoch 10/20
# 2/2 [==============================] - 0s 16ms/step - loss: 1.3684 - accuracy: 0.2812 - val_loss: 1.4320 - val_accuracy: 0.2188
# Epoch 11/20
# 2/2 [==============================] - 0s 16ms/step - loss: 1.3657 - accuracy: 0.2812 - val_loss: 1.4323 - val_accuracy: 0.2188
# Epoch 12/20
# 2/2 [==============================] - 0s 16ms/step - loss: 1.3626 - accuracy: 0.2812 - val_loss: 1.4322 - val_accuracy: 0.2188
# Epoch 13/20
# 2/2 [==============================] - 0s 16ms/step - loss: 1.3609 - accuracy: 0.2812 - val_loss: 1.4304 - val_accuracy: 0.2188
# Epoch 14/20
# 2/2 [==============================] - 0s 16ms/step - loss: 1.3572 - accuracy: 0.2812 - val_loss: 1.4287 - val_accuracy: 0.2188
# Epoch 15/20
# 2/2 [==============================] - 0s 17ms/step - loss: 1.3545 - accuracy: 0.2812 - val_loss: 1.4269 - val_accuracy: 0.2188
# Epoch 16/20
# 2/2 [==============================] - 0s 17ms/step - loss: 1.3522 - accuracy: 0.2812 - val_loss: 1.4255 - val_accuracy: 0.2188
# Epoch 17/20
# 2/2 [==============================] - 0s 17ms/step - loss: 1.3481 - accuracy: 0.2812 - val_loss: 1.4225 - val_accuracy: 0.2188
# Epoch 18/20
# 2/2 [==============================] - 0s 16ms/step - loss: 1.3449 - accuracy: 0.2812 - val_loss: 1.4206 - val_accuracy: 0.2188
# Epoch 19/20
# 2/2 [==============================] - 0s 16ms/step - loss: 1.3420 - accuracy: 0.2969 - val_loss: 1.4188 - val_accuracy: 0.2500
# Epoch 20/20
# 2/2 [==============================] - 0s 16ms/step - loss: 1.3385 - accuracy: 0.2969 - val_loss: 1.4164 - val_accuracy: 0.2500
